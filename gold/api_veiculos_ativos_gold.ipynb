# %%
df = spark.sql("""select *
                        from sp_trans2.silver.api_veiculos_ativos""")

# %%
display(df)

# %%
df.write.mode("overwrite").option("mergeSchema", "true").saveAsTable("sp_trans2.gold.fato_veiculos_ativos")
