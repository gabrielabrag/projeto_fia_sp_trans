# %%
df = (spark.read
                .option("header", "true")      # força sem header
                .option("inferSchema", "true")
                .option("delimiter", ",")
                .csv("/Volumes/sp_trans2/landing/carga_fria/agency.txt"))
display(df)

# %%
df.write.mode("overwrite").saveAsTable("sp_trans2.bronze.agency")
