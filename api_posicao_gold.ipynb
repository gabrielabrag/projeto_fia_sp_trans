# %%
df = spark.sql("""select linha_id,
                        linha_cod,
                        sentido_linha,
                        letreiro_principal,
                        letreiro_secundario,
                        fl_acessivel,
                        veiculo_prefixo,
                        timestamp_api,
                        lat,
                        lon
                        from sp_trans2.silver.api_posicao""")

# %%
df.write.mode("append").saveAsTable("sp_trans2.gold.fato_posicao")
