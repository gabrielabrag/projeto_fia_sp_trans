# %%
df = spark.table("sp_trans2.bronze.api_veiculos_ativos")

# %%
df=df.withColumnRenamed("codigo_linha", "linha_id")

# %%
display(df)

# %%
df.write.mode("overwrite").option("mergeSchema", "true").saveAsTable("sp_trans2.silver.api_veiculos_ativos")
